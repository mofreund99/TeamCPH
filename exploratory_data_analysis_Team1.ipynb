# %%
# Import necessary libraries\n
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

# Load the data
# `model_df` caused a NameError because it wasn't defined; use the actual CSV filename instead.
df = pd.read_csv("model_df.csv")

# Number of samples
num_samples = df.shape[0]

# Number of features
num_features = df.shape[1]

# Display these dataset characteristics
print(f"Number of samples: {num_samples}")
print(f"Number of features: {num_features}")

# Display the first few rows of the dataframe to show the structure
print("Example data:")
print(df.head())
# Out:
# Number of samples: 9292
# Number of features: 18
# Example data:
#        Umsatz  Warengruppe  holiday  IsWeekend  IsNewYears  Easter  \
# 0  135.500244            1        1          0           0       0
# 1  136.048383            1        1          0           0       0
# 2  135.132314            1        1          0           0       0
# 3  138.549393            1        1          0           0       0
# 4  101.447511            1        1          0           0       0
#
#    KielerWoche    sin_1y    cos_1y    sin_2y  Revenue_lag1  Revenue_lag7  \
# 0            0 -0.109446 -0.993993  0.217577     92.637755    148.828353
# 1            0 -0.126528 -0.991963  0.251022    135.500244    159.793757
# 2            0 -0.143572 -0.989640  0.284170    136.048383    111.885594
# 3            0 -0.160575 -0.987024  0.316982    135.132314    168.864941
# 4            0 -0.177529 -0.984116  0.349418    138.549393    171.280754
#
#    WG_2  WG_3  WG_4  WG_5  WG_6  log_Umsatz
# 0     0     0     0     0     0    4.916326
# 1     0     0     0     0     0    4.920334
# 2     0     0     0     0     0    4.913627
# 3     0     0     0     0     0    4.938419
# 4     0     0     0     0     0    4.629351

# %%
# Check for missing values
missing_values = df.isnull().sum()
missing_values
# Out:
# Umsatz          0
# Warengruppe     0
# holiday         0
# IsWeekend       0
# IsNewYears      0
# Easter          0
# KielerWoche     0
# sin_1y          0
# cos_1y          0
# sin_2y          0
# Revenue_lag1    0
# Revenue_lag7    0
# WG_2            0
# WG_3            0
# WG_4            0
# WG_5            0
# WG_6            0
# log_Umsatz      0
# dtype: int64

# %%
# Example: Plotting histograms of all numerical features
df.hist(figsize=(12, 12))
plt.show()

# %%
# Example: Checking for class imbalance in a classification problem
# sns.countplot(x='target_variable', data=df)

# Your code to investigate possible biases goes here

# %%
# Example: Plotting a heatmap to show feature correlations
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True)
plt.show()
